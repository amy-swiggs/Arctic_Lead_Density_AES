# %%
import pandas as pd
import numpy as np
from numpy import transpose as T
import glob
import os
import cartopy
import cartopy.crs as ccrs
import matplotlib
from matplotlib.lines import Line2D
import matplotlib.pyplot as plt
import matplotlib.colors as mcolors
import matplotlib.patches as mpatches
import matplotlib.lines as mlines
from matplotlib.ticker import MultipleLocator
from matplotlib.gridspec import GridSpec
import matplotlib.cm as cm
import geopandas as gpd
from scipy.optimize import curve_fit
from scipy import stats
from netCDF4 import Dataset
import scipy
from scipy import stats
from scipy.ndimage import distance_transform_edt
from datetime import datetime,timedelta
from numpy import genfromtxt as gftxt
import regionmask
from pyproj import Transformer
from datetime import datetime,timedelta
import sys
from pathlib import Path

# %%
sys.path.append(str(Path.cwd().parents[0]))
from utils.grid_map_functions import(land_masking, defining_grids)

map_projection = ccrs.NorthPolarStereo()

x_grid_edge_25,y_grid_edge_25,new_x_edge_25,new_y_edge_25 = defining_grids(map_projection,[-180, 180, 90, 65],25000,'edge')
x_grid_centre_25,y_grid_centre_25,new_x_centre_25,new_y_centre_25 = defining_grids(map_projection,[-180, 180, 90, 65],25000,'centre')
land_mask_25 = land_masking(new_x_centre_25,new_y_centre_25,map_projection)

transformer = Transformer.from_crs(map_projection, "EPSG:4326", always_xy=True)
lon0, lat0 = transformer.transform(new_x_centre_25.ravel(), new_y_centre_25.ravel())
lon1 = lon0.reshape(new_x_centre_25.shape)
lat1 = lat0.reshape(new_y_centre_25.shape)

from utils.stats_functions import(absdiff,corr,rmsd)

#base_dir = ('/Users/amyswiggs/Desktop/Spring_2026/Arctic_Sea_Surface_Classification/Data/')
base_dir = ('C:/Users/Administrator/Documents/Spring_2026/Arctic_Sea_Surface_Classification/Data/')

# %%
def retrieving_fractions(input_folder,yrs):
    fractions = {}
    for array in input_folder:
        fraction0 = np.load(array)
        fraction = np.where(land_mask_buffered, np.nan, fraction0)
        fname = os.path.basename(array)
        date = fname.split('_')[0]
        year = str(date[0:4])
        month = str(date[4:6])
        if year in yrs:
            if year == '2018' and int(month) < 10:# don't include jan - apr for 2018
                continue
            if year == '2025' and int(month) > 4: # don't include oct - dec for 2025
                continue
            fractions[date] = fraction
    return(fractions)


def monthly_averages_allyears(fractions_dict,months):
    monthly_groups = {m: [] for m in months}
    for date, arr in fractions_dict.items():
        month = date[4:6]
        if month in monthly_groups:
            monthly_groups[month].append(arr)

    monthly_fractions = {}
    
    for month, arrays in monthly_groups.items():
        stacked = np.stack(arrays, axis=0) 
        monthly_fractions[month] = np.nanmean(stacked, axis=0)

    return(monthly_fractions)
    
def add_land_buffer_distance(land_mask, grid_spacing_km, buffer_km):
    """
    Create buffer based on real distance (km)
    """
    # दूरी from land: compute distance from NON-land
    distance = distance_transform_edt(~land_mask) * grid_spacing_km
    
    # mask where within buffer distance
    buffer_mask = distance <= buffer_km
    
    return land_mask | buffer_mask

land_mask_buffered = add_land_buffer_distance(land_mask_25,grid_spacing_km=25,buffer_km=5)

# %% [markdown]
# # Monthly Maps

# %%
req_yrs = ['2018','2019','2020','2021','2022','2023','2024','2025']
winter_months = ['10','11','12','01','02','03','04']

ku_lead_folder = sorted(glob.glob(f'{base_dir}Monthly_Averages/25km/S3_CS2_Merged/*_Lead_Density.npy'))
ku_lead_fractions = retrieving_fractions(ku_lead_folder,req_yrs)
ku_lead_fractions_avgs = monthly_averages_allyears(ku_lead_fractions,winter_months)

multi_lead_folder = sorted(glob.glob(f'{base_dir}Monthly_Averages/25km/Merged/*_Lead_Density.npy'))
multi_lead_fractions = retrieving_fractions(multi_lead_folder,req_yrs)
multi_lead_fractions_avgs = monthly_averages_allyears(multi_lead_fractions,winter_months)
# Out:
# C:\Users\Administrator\AppData\Local\Temp\2\ipykernel_8452\4009339073.py:30: RuntimeWarning: Mean of empty slice
#   monthly_fractions[month] = np.nanmean(stacked, axis=0)

# %% [markdown]
# ## KuLa Leads

# %%
multi_monthly_leads = sorted(glob.glob(f'{base_dir}Monthly_Averages/25km/Merged_Full_Record/*_Merged_Lead_Density.npy'))

monthly_multi_leads = {}
monthly_average_multi_leads = []

for lead_file in multi_monthly_leads[:]:
    lead_data0 = np.load(lead_file)
    lead_data = np.where(land_mask_buffered, np.nan, lead_data0)
    
    filename = os.path.basename(lead_file)
    date_key = filename.split('_Merged')[0]

    monthly_multi_leads[date_key] = lead_data

    avg_lead_data = np.nanmean(lead_data)
    monthly_average_multi_leads.append({'Date':date_key,'Lead Density (%)':avg_lead_data})
    
monthly_average_multi_leads_df = pd.DataFrame(monthly_average_multi_leads)
monthly_average_multi_leads_df['Datetime'] = pd.to_datetime(monthly_average_multi_leads_df['Date'],
    format='%Y%m')

# %%
monthly_average_multi_leads_df['Year'] = monthly_average_multi_leads_df['Datetime'].dt.year
monthly_average_multi_leads_df['Month'] = monthly_average_multi_leads_df['Datetime'].dt.month

month_map = {1: 'Jan', 2: 'Feb', 3: 'Mar', 4: 'Apr',10: 'Oct', 11: 'Nov', 12: 'Dec'}
monthly_average_multi_leads_df['MonthLabel'] = monthly_average_multi_leads_df['Month'].map(month_map)

month_order = ['Oct','Nov','Dec','Jan','Feb','Mar','Apr']

monthly_average_multi_leads_df['MonthLabel'] = pd.Categorical(monthly_average_multi_leads_df['Month'].map(month_map),
    categories=month_order,ordered=True)

# %%
multi_stats = (monthly_average_multi_leads_df
    .groupby('MonthLabel')['Lead Density (%)']
    .agg(['mean', 'std', 'min', 'max'])
    .reindex(month_order))

# %% [markdown]
# ## Ku Leads

# %%
ku_monthly_leads = sorted(glob.glob(f'{base_dir}Monthly_Averages/25km/S3_CS2_Merged_Full_Record/*_Merged_Lead_Density.npy'))

monthly_ku_leads = {}
monthly_average_ku_leads = []

for lead_file in ku_monthly_leads[:]:
    lead_data0 = np.load(lead_file)
    lead_data = np.where(land_mask_buffered, np.nan, lead_data0)
    
    filename = os.path.basename(lead_file)
    date_key = filename.split('_S3_CS2_Merged')[0]

    monthly_ku_leads[date_key] = lead_data

    avg_lead_data = np.nanmean(lead_data)
    monthly_average_ku_leads.append({'Date':date_key,'Lead Density (%)':avg_lead_data})
    
monthly_average_ku_leads_df = pd.DataFrame(monthly_average_ku_leads)
monthly_average_ku_leads_df['Datetime'] = pd.to_datetime(monthly_average_ku_leads_df['Date'],
    format='%Y%m')

# %%
monthly_average_ku_leads_df['Year'] = monthly_average_ku_leads_df['Datetime'].dt.year
monthly_average_ku_leads_df['Month'] = monthly_average_ku_leads_df['Datetime'].dt.month

month_map = {1: 'Jan', 2: 'Feb', 3: 'Mar', 4: 'Apr',10: 'Oct', 11: 'Nov', 12: 'Dec'}
monthly_average_ku_leads_df['MonthLabel'] = monthly_average_ku_leads_df['Month'].map(month_map)

month_order = ['Oct','Nov','Dec','Jan','Feb','Mar','Apr']

monthly_average_ku_leads_df['MonthLabel'] = pd.Categorical(monthly_average_ku_leads_df['Month'].map(month_map),
    categories=month_order,ordered=True)

# %%
ku_stats = (monthly_average_ku_leads_df
    .groupby('MonthLabel')['Lead Density (%)']
    .agg(['mean', 'std', 'min', 'max'])
    .reindex(month_order))

# %% [markdown]
# # Plotting

# %% [markdown]
# ## Version 1.0

# %%
cs2_lead_colour = '#2D74BE'
s3_lead_colour = '#489963'
is2_lead_colour = '#733498'
merged_lead_colour = '#C6482F'
modis_lead_colour = '#F0CF65'
s3_cs2_merged_lead_colour = 'grey'

months = ['10','11','12','01','02','03','04']
month_labels = {'10': 'Oct', '11': 'Nov', '12': 'Dec',
    '01': 'Jan', '02': 'Feb', '03': 'Mar', '04': 'Apr'}
modis_month_labels = {'11': 'Nov', '12': 'Dec',
    '01': 'Jan', '02': 'Feb', '03': 'Mar', '04': 'Apr'}

fig = plt.figure(figsize=(20,20), layout='constrained')

gs = fig.add_gridspec(
    4, 7,
    height_ratios=[1.5, 1.5, 2.5, 2.5]
)
lead_kwargs = dict(cmap='plasma',transform=map_projection,
    vmin=0,vmax=40,zorder=1)

# --- Add map row --- #
map_axes_row1 = []
map_axes_row2 = []

for col in range(7):
    ax1 = fig.add_subplot(gs[0, col], projection=map_projection)
    map_axes_row1.append(ax1)

    ax2 = fig.add_subplot(gs[1, col], projection=map_projection)
    map_axes_row2.append(ax2)

# --- Add timeseries row --- #
ts_ax = fig.add_subplot(gs[2, :])

yr_ax = fig.add_subplot(gs[3, :])


# --- Plot monthly maps --- #
for col, month in enumerate(months):
    ku_ax = map_axes_row1[col]

    ku_leads = ku_ax.pcolormesh(x_grid_centre_25,
        y_grid_centre_25,
        ku_lead_fractions_avgs[month],
        **lead_kwargs)

    ku_ax.coastlines(linewidth=0.2,zorder=2.5)
    ku_ax.gridlines(linewidth=0.3, color='k', alpha=0.5, linestyle=':')
    ku_ax.add_feature(cartopy.feature.LAND, color=('gainsboro'), edgecolor='black',zorder=2)
    ku_ax.add_feature(cartopy.feature.OCEAN, color=('azure'),edgecolor='black',zorder=0)
    ku_ax.set_extent([-180, 180, 90, 70], ccrs.PlateCarree())
    ku_ax.set_title(month_labels[month], fontsize=16)

    multi_ax = map_axes_row2[col]

    multi_leads = multi_ax.pcolormesh(x_grid_centre_25,
        y_grid_centre_25,
        multi_lead_fractions_avgs[month],
        **lead_kwargs)

    multi_ax.coastlines(linewidth=0.2,zorder=2.5)
    multi_ax.gridlines(linewidth=0.3, color='k', alpha=0.5, linestyle=':')
    multi_ax.add_feature(cartopy.feature.LAND, color=('gainsboro'), edgecolor='black',zorder=2)
    multi_ax.add_feature(cartopy.feature.OCEAN, color=('azure'),edgecolor='black',zorder=0)
    multi_ax.set_extent([-180, 180, 90, 70], ccrs.PlateCarree())
    multi_ax.set_title(month_labels[month], fontsize=16)

cbar = fig.colorbar(multi_leads, ax=map_axes_row2, orientation='horizontal', fraction=0.1, pad=0.05,
                    extend='both')
cbar.set_label('Lead Density (%)',fontsize=16)

# --- Plot monthly timeseries --- #
for month, group in monthly_average_multi_leads_df.groupby('MonthLabel'):
    ts_ax.plot(group['Year'],group['Lead Density (%)'],
        label=month,linestyle='-',linewidth=1.5)

ts_ax.grid(alpha=0.3)
ts_ax.tick_params(axis='x', labelrotation=25)
ts_ax.tick_params(axis='both', which='major', labelsize=14)
ts_ax.set_xlabel('Year',fontsize=16)
ts_ax.set_ylabel('Lead Density (%)',fontsize=16)
ts_ax.legend(fontsize=16,loc='lower left')
ts_ax.set_ylim([8,20])
ts_ax.set_xlim([2008.5,2026])

# --- add arrows --- #
cs2_start = 2010
cs2_end = 2025
ts_ax.annotate('', xy=(cs2_end, 18), xytext=(cs2_start, 18),
    arrowprops=dict(arrowstyle='<->', color='black', linewidth=2))
mid = cs2_start + (cs2_end - cs2_start) / 4
ts_ax.text(mid, 18.2, 'CS2',ha='center', va='bottom', fontsize=16,color='black')

s3_start = 2016.4
ts_ax.annotate('', xy=(cs2_end, 18.5), xytext=(s3_start, 18.5),
    arrowprops=dict(arrowstyle='<->', color='black', linewidth=2))
mid = s3_start + (cs2_end - s3_start) / 8
ts_ax.text(mid, 18.7, 'S3',ha='center', va='bottom', fontsize=16,color='black')

is2_start = 2018.8
ts_ax.annotate('', xy=(cs2_end, 19), xytext=(is2_start, 19),
    arrowprops=dict(arrowstyle='<->', color='black', linewidth=2))
mid = is2_start + (cs2_end - is2_start) / 2
ts_ax.text(mid, 19.2, 'IS2',ha='center', va='bottom', fontsize=16,color='black')

# --- Plot yearly timeseries ---
yr_ax.plot(multi_stats.index,multi_stats['mean'],
    color=merged_lead_colour,linewidth=3,label='KuLa-Leads All Year Mean',zorder=2)

yr_ax.fill_between(multi_stats.index,
    multi_stats['mean'] - multi_stats['std'],
    multi_stats['mean'] + multi_stats['std'],
    color=merged_lead_colour,alpha=0.4,zorder=1)

yr_ax.plot(ku_stats.index,ku_stats['mean'],
    color=s3_cs2_merged_lead_colour,linewidth=3,label='Ku-Leads All Year Mean',zorder=2)

yr_ax.fill_between(ku_stats.index,
    ku_stats['mean'] - ku_stats['std'],
    ku_stats['mean'] + ku_stats['std'],
    color=s3_cs2_merged_lead_colour,alpha=0.4,zorder=1)

yr_ax.grid(alpha=0.3)
yr_ax.tick_params(axis='x', labelrotation=25)
yr_ax.tick_params(axis='both', which='major', labelsize=14)
yr_ax.set_xlabel('Month',fontsize=16)
yr_ax.set_ylabel('Lead Density (%)',fontsize=16)
yr_ax.legend(fontsize=14)
yr_ax.set_ylim([8,17])

fig.text(0.03,0.99,'(a)',fontsize=16)
fig.text(0.03,0.81,'(b)',fontsize=16)
fig.text(0.03,0.64,'(c)',fontsize=16)
fig.text(0.03,0.32,'(d)',fontsize=16)

plt.show()

#fig.savefig('/Users/amyswiggs/Desktop/Spring_2026/Arctic_Sea_Surface_Classification/Arctic_Lead_Density_AES/Figures/Fig4.png',dpi=300,bbox_inches="tight")

# %% [markdown]
# ## Version 2.0

# %%
cs2_lead_colour = '#2D74BE'
s3_lead_colour = '#489963'
is2_lead_colour = '#733498'
merged_lead_colour = '#C6482F'
modis_lead_colour = '#F0CF65'
s3_cs2_merged_lead_colour = 'grey'

lead_datasets = {0: ku_lead_fractions_avgs,1: multi_lead_fractions_avgs}

dataset_names = ['Ku', 'KuLa']

months = ['10', '11', '12', '01', '02', '03', '04']

month_names = {
    '10': 'October',
    '11': 'November',
    '12': 'December',
    '01': 'January',
    '02': 'February',
    '03': 'March',
    '04': 'April'
}

lead_kwargs = dict(cmap='plasma',transform=map_projection,
    vmin=0,vmax=40,zorder=1)

# Fig Sizing & axes

fig = plt.figure(figsize=(14, 24), layout='constrained')

gs = fig.add_gridspec(
    6, 4,
    height_ratios=[1.8, 1.8, 1.8, 1.8, 2.2, 2.2])
# 6 rows × 4 columns
#
# Row 0: Ku Oct, Nov, Dec, Jan
# Row 1: Ku Feb, Mar, Apr
# Row 2: KuLa Oct, Nov, Dec, Jan
# Row 3: KuLa Feb, Mar, Apr
# Row 4: Monthly timeseries
# Row 5: Yearly timeseries

ax = np.empty((4, 4), dtype=object)

for row in range(4):
    for col in range(4):
        ax[row, col] = fig.add_subplot(gs[row, col],projection=map_projection)

# Plot maps
for dataset_idx, (dataset_key, data) in enumerate(lead_datasets.items()):

    start_row = dataset_idx * 2

    for month_idx, month in enumerate(months):

        # First 4 months = first row
        # Last 3 months = second row
        row = start_row + month_idx // 4
        col = month_idx % 4

        leads = ax[row, col].pcolormesh(x_grid_centre_25,y_grid_centre_25,
            data[month],**lead_kwargs)

        ax[row, col].coastlines(linewidth=0.2,zorder=2.5)
        ax[row, col].gridlines(linewidth=0.3,color='k',alpha=0.5,linestyle=':')
        ax[row, col].add_feature(cartopy.feature.LAND,color='gainsboro',edgecolor='black',zorder=2)
        ax[row, col].add_feature(cartopy.feature.OCEAN,color='azure',edgecolor='black',zorder=0)
        ax[row, col].set_extent([-180, 180, 90, 70],ccrs.PlateCarree())
        ax[row, col].set_title(month_names[month],fontsize=14)

# Hide unused map axes
ax[1, 3].set_visible(False)
ax[3, 3].set_visible(False)

# Labels
ax[0, 0].text(-0.12, 0.5,'Ku',transform=ax[0, 0].transAxes,
    fontsize=16,va='center',ha='right',fontweight='bold')

ax[2, 0].text(-0.12, 0.5,'KuLa',transform=ax[2, 0].transAxes,
    fontsize=16,va='center',ha='right',fontweight='bold')

cbar = fig.colorbar(leads, ax=ax, location='bottom',orientation='horizontal', pad=0.02,use_gridspec=True,
                    shrink=0.4,extend='both')
cbar.ax.tick_params(labelsize=14)
cbar.set_label('Lead Density (%)',fontsize=16)


# Monthly timeseries
ts_ax = fig.add_subplot(gs[4, :])

for month, group in monthly_average_multi_leads_df.groupby('MonthLabel'):
    ts_ax.plot(group['Year'],group['Lead Density (%)'],
        label=month,linestyle='-',linewidth=1.5)

ts_ax.grid(alpha=0.3)
ts_ax.tick_params(axis='x', labelrotation=25)
ts_ax.tick_params(axis='both', which='major', labelsize=14)
ts_ax.set_xlabel('Year',fontsize=16)
ts_ax.set_ylabel('Lead Density (%)',fontsize=16)
ts_ax.legend(fontsize=16,loc='lower left')
ts_ax.set_ylim([8,20])
ts_ax.set_xlim([2008.5,2026])


# Add coverage arrows
cs2_start = 2010
cs2_end = 2025

ts_ax.annotate('', xy=(cs2_end, 18), xytext=(cs2_start, 18),
    arrowprops=dict(arrowstyle='<->', color='black', linewidth=2))
mid = cs2_start + (cs2_end - cs2_start) / 4
ts_ax.text(mid, 18.2, 'CS2',ha='center', va='bottom', fontsize=16,color='black')

s3_start = 2016.4
ts_ax.annotate('', xy=(cs2_end, 18.5), xytext=(s3_start, 18.5),
    arrowprops=dict(arrowstyle='<->', color='black', linewidth=2))
mid = s3_start + (cs2_end - s3_start) / 8
ts_ax.text(mid, 18.7, 'S3',ha='center', va='bottom', fontsize=16,color='black')

is2_start = 2018.8
ts_ax.annotate('', xy=(cs2_end, 19), xytext=(is2_start, 19),
    arrowprops=dict(arrowstyle='<->', color='black', linewidth=2))
mid = is2_start + (cs2_end - is2_start) / 2
ts_ax.text(mid, 19, 'IS2',ha='center', va='bottom', fontsize=16,color='black')


# Yearly timeseries
yr_ax = fig.add_subplot(gs[5, :])

yr_ax.plot(multi_stats.index,multi_stats['mean'],
    color=merged_lead_colour,linewidth=3,label='KuLa-Leads All Year Mean',zorder=2)

yr_ax.fill_between(multi_stats.index,
    multi_stats['mean'] - multi_stats['std'],
    multi_stats['mean'] + multi_stats['std'],
    color=merged_lead_colour,alpha=0.4,zorder=1)

yr_ax.plot(ku_stats.index,ku_stats['mean'],
    color=s3_cs2_merged_lead_colour,linewidth=3,label='Ku-Leads All Year Mean',zorder=2)

yr_ax.fill_between(ku_stats.index,
    ku_stats['mean'] - ku_stats['std'],
    ku_stats['mean'] + ku_stats['std'],
    color=s3_cs2_merged_lead_colour,alpha=0.4,zorder=1)

yr_ax.grid(alpha=0.3)
yr_ax.tick_params(axis='x', labelrotation=25)
yr_ax.tick_params(axis='both', which='major', labelsize=14)
yr_ax.set_xlabel('Month',fontsize=16)
yr_ax.set_ylabel('Lead Density (%)',fontsize=16)
yr_ax.legend(fontsize=16)
yr_ax.set_ylim([8,17])

# Panel labels
ax[0, 0].text(-0.28, 1.,'(a)',transform=ax[0, 0].transAxes,
    fontsize=16,va='bottom')

ax[2, 0].text(-0.28, 1,'(b)',transform=ax[2, 0].transAxes,
    fontsize=16,va='bottom')

ts_ax.text(-0.02, 1.05,'(c)',transform=ts_ax.transAxes,
    fontsize=16,va='bottom')

yr_ax.text(-0.02, 1.05,'(d)',transform=yr_ax.transAxes,
    fontsize=16,va='bottom')


plt.show()

#fig.savefig('/Users/amyswiggs/Desktop/Spring_2026/Arctic_Sea_Surface_Classification/Arctic_Lead_Density_AES/Resubmission_Figures/Fig6.1.png',dpi=300,bbox_inches="tight")
fig.savefig(f"{base_dir}Fig6.1.png",dpi=300,bbox_inches="tight")

# %% [markdown]
# # Stats

# %%
trend_results = []
for month, group in monthly_average_multi_leads_df.groupby('Month'):
    group = group.sort_values('Year')
    x = group['Year'].values
    y = group['Lead Density (%)'].values

    if len(x) < 3:
        continue

    slope, intercept, r_value, p_value, std_err = stats.linregress(x, y)

    trend_results.append({'Month': month,
        'MonthLabel': group['MonthLabel'].iloc[0],
        'Slope': slope,
        'p_value': p_value,
        'r_squared': r_value**2,
        'Significant (p<0.05)': p_value < 0.05})

trend_df = pd.DataFrame(trend_results).sort_values('Month')

# %%
trend_df
# Out:
#    Month MonthLabel     Slope   p_value  r_squared  Significant (p<0.05)
# 0      1        Jan -0.103428  0.003413   0.495250                  True
# 1      2        Feb -0.031700  0.298426   0.082776                 False
# 2      3        Mar -0.041033  0.233545   0.107205                 False
# 3      4        Apr -0.067261  0.014136   0.381548                  True
# 4     10        Oct  0.206426  0.000119   0.722244                  True
# 5     11        Nov -0.003912  0.928259   0.000648                 False
# 6     12        Dec -0.029537  0.310555   0.078891                 False
