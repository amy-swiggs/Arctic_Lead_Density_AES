# %%
import pandas as pd
import numpy as np
from numpy import transpose as T
import glob
import os
import cartopy
import cartopy.crs as ccrs
import matplotlib
from matplotlib.lines import Line2D
import matplotlib.pyplot as plt
import matplotlib.colors as mcolors
import matplotlib.patches as mpatches
import matplotlib.lines as mlines
from matplotlib.ticker import MultipleLocator
from matplotlib.gridspec import GridSpec
import matplotlib.cm as cm
import geopandas as gpd
from scipy.optimize import curve_fit
from netCDF4 import Dataset
import scipy
from scipy import stats
from scipy.ndimage import distance_transform_edt
from datetime import datetime,timedelta
from numpy import genfromtxt as gftxt
import regionmask
from pyproj import Transformer
from datetime import datetime,timedelta
import sys
from pathlib import Path

# %%
sys.path.append(str(Path.cwd().parents[1]))
from utils.grid_map_functions import(land_masking, defining_grids)

map_projection = ccrs.NorthPolarStereo()
cartopy_crs = ccrs.NorthPolarStereo(central_longitude=0)

x_grid_edge_25,y_grid_edge_25,new_x_edge_25,new_y_edge_25 = defining_grids(map_projection,[-180, 180, 90, 65],25000,'edge')
x_grid_centre_25,y_grid_centre_25,new_x_centre_25,new_y_centre_25 = defining_grids(map_projection,[-180, 180, 90, 65],25000,'centre')
land_mask_25 = land_masking(new_x_centre_25,new_y_centre_25,map_projection)

x_grid_edge_10,y_grid_edge_10,new_x_edge_10,new_y_edge_10 = defining_grids(map_projection,[-180, 180, 90, 65],10000,'edge')
x_grid_centre_10,y_grid_centre_10,new_x_centre_10,new_y_centre_10 = defining_grids(map_projection,[-180, 180, 90, 65],10000,'centre')
land_mask_10 = land_masking(new_x_centre_10,new_y_centre_10,map_projection)

x_grid_edge_5,y_grid_edge_5,new_x_edge_5,new_y_edge_5 = defining_grids(map_projection,[-180, 180, 90, 65],5000,'edge')
x_grid_centre_5,y_grid_centre_5,new_x_centre_5,new_y_centre_5 = defining_grids(map_projection,[-180, 180, 90, 65],5000,'centre')
land_mask_5 = land_masking(new_x_centre_5,new_y_centre_5,map_projection)

transformer = Transformer.from_crs(map_projection, "EPSG:4326", always_xy=True)
lon0, lat0 = transformer.transform(new_x_centre_25.ravel(), new_y_centre_25.ravel())
lon1 = lon0.reshape(new_x_centre_25.shape)
lat1 = lat0.reshape(new_y_centre_25.shape)

from utils.stats_functions import(absdiff,corr,rmsd)

base_dir = ('/Users/amyswiggs/Desktop/Spring_2026/Arctic_Sea_Surface_Classification/Data/')

# %% [markdown]
# # Loading Arrays

# %%
#is2_201810 = np.load(f'{base_dir}5km_Grid/Density_Arrays/201810_5km_IS2_Lead_Density.npy')
cs2_201810 = np.load(f'{base_dir}5km_Grid/Density_Arrays/201810_10km_CS2_Lead_Density.npy')
s3_201810 = np.load(f'{base_dir}5km_Grid/Density_Arrays/201810_10km_S3_Lead_Density.npy')

multi_201810_stack = np.stack([cs2_201810,s3_201810],axis=0)
multi_201810 = np.nanmean(multi_201810_stack,axis=0)
# Out:
# /var/folders/q1/prwbhm6j6x1gcchb7r0p2kyh0000gn/T/ipykernel_1791/3395106362.py:6: RuntimeWarning: Mean of empty slice
#   multi_201810 = np.nanmean(multi_201810_stack,axis=0)

# %%
#is2_202410 = np.load(f'{base_dir}5km_Grid/Density_Arrays/201810_5km_IS2_Lead_Density.npy')
cs2_202410 = np.load(f'{base_dir}5km_Grid/Density_Arrays/202410_10km_CS2_Lead_Density.npy')
s3_202410 = np.load(f'{base_dir}5km_Grid/Density_Arrays/202410_10km_S3_Lead_Density.npy')

multi_202410_stack = np.stack([cs2_202410,s3_202410],axis=0)
multi_202410 = np.nanmean(multi_202410_stack,axis=0)
# Out:
# /var/folders/q1/prwbhm6j6x1gcchb7r0p2kyh0000gn/T/ipykernel_1791/1571704961.py:6: RuntimeWarning: Mean of empty slice
#   multi_202410 = np.nanmean(multi_202410_stack,axis=0)

# %%
fig = plt.figure(figsize=(6,6))
ax = plt.axes(projection=map_projection)

pcm = ax.pcolormesh(new_x_centre_10,new_y_centre_10, multi_202410,
    transform=map_projection,
    cmap='viridis',vmin=0,vmax=40)

ax.coastlines()
ax.set_extent([-180, 180, 60, 90], ccrs.PlateCarree())

plt.colorbar(pcm, ax=ax, label='Lead Density')
plt.show()

# %%
plt_projection = ccrs.NorthPolarStereo(central_longitude=-90) 

lead_kwargs = dict(cmap='plasma', vmin=0, vmax=40)

fig = plt.figure(figsize=(6, 6))
ax = plt.axes(projection=plt_projection)

pcm = ax.pcolormesh(
    new_x_centre_10, new_y_centre_10, multi_201810,
    transform=map_projection,
    **lead_kwargs,
    zorder=1)

ax.coastlines(linewidth=0.2, zorder=2.5)
ax.gridlines(linewidth=0.3, color='k', alpha=0.5, linestyle=':')
ax.add_feature(cartopy.feature.LAND,  color='gainsboro', edgecolor='black', zorder=2)
ax.add_feature(cartopy.feature.OCEAN, color='azure',     edgecolor='black', zorder=0)
ax.set_extent([-130, -72, 75, 82], ccrs.PlateCarree())  # adjust as needed

#plt.colorbar(pcm, ax=ax, label='Lead Density')
plt.show()

# %%
plt_projection = ccrs.NorthPolarStereo(central_longitude=-90) 

lead_kwargs = dict(cmap='plasma', vmin=0, vmax=40)

fig = plt.figure(figsize=(6, 6))
ax = plt.axes(projection=plt_projection)

pcm = ax.pcolormesh(
    new_x_centre_10, new_y_centre_10, multi_202410,
    transform=map_projection,
    **lead_kwargs,
    zorder=1)

ax.coastlines(linewidth=0.2, zorder=2.5)
ax.gridlines(linewidth=0.3, color='k', alpha=0.5, linestyle=':')
ax.add_feature(cartopy.feature.LAND,  color='gainsboro', edgecolor='black', zorder=2)
ax.add_feature(cartopy.feature.OCEAN, color='azure',     edgecolor='black', zorder=0)
ax.set_extent([-130, -75, 76, 82], ccrs.PlateCarree())  # adjust as needed

#plt.colorbar(pcm, ax=ax, label='Lead Density')
plt.show()
